# %% [markdown]
# <a href="https://colab.research.google.com/github/allansuzuki/Brazil_Covid19_Analysis/blob/main/COVID_19_Background_in_Brazil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # COVID-19 Background in Brazil (2022)
#
# COVID-19 is an infectious disease caused by a newly discovered coronavirus.
#
# Transmitted primarily through droplets from the coughs or sneezes of infected people, the severity of symptoms varies greatly from person to person.
#
# The fact is not much in known about COVID-19. Studies are being carried out all over the world, the health all over the world is developing, but the results are still not conclusive and definitive.
#
#
# <center><img alt="Colaboratory logo" width="50%" src="https://raw.githubusercontent.com/carlosfab/dsnp2/master/img/covid19.jpg"></center>
#
# Currently, it is observed that about 80% of confirmed cases are asymptomatic and/or rapid. Most people who fall into this group recover without any sequelae.
#
# However, 15% of people will have serious infections and need oxygen. The rest of the people, representing 5%, will be classified as very serious infections and will need assisted ventilation, through mechanical respirators in the hospital.
#
# In order to aware about the  COVID-19 situation in Brazil, I will carry out an analysis of public data on the disease.

# %% [markdown]
# # Data gathering
#
# The COVID-9 data was obtained from [*Our World in Data*](https://ourworldindata.org/coronavirus) website, maintained by themselves and updated daily (today was 8th June 2022).
#
# ## Fields description
#
# * **iso_code**: ISO 3166-1 alpha-3 – three-letter country codes
# * **continent**: Continent of the geographical location
# * **location**: Geographical location
# * **date**: Date of observation
# * **total_cases**: Total confirmed cases of COVID-19. Counts can include probable cases, where reported.
# * **new_cases**: New confirmed cases of COVID-19. Counts can include probable cases, where reported. In rare cases where our source reports a negative daily change due to a data correction, we set this metric to NA.
# * **new_cases_smoothed**: New confirmed cases of COVID-19 (7-day smoothed). Counts can include probable cases, where reported.
# * **total_deaths**: Total deaths attributed to COVID-19. Counts can include probable deaths, where reported.
# * **new_deaths**: New deaths attributed to COVID-19. Counts can include probable deaths, where reported. In rare cases where our source reports a negative daily change due to a data correction, we set this metric to NA.
# * **new_deaths_smoothed**: New deaths attributed to COVID-19 (7-day smoothed). Counts can include probable deaths, where reported.
# * **total_cases_per_million**: Total confirmed cases of COVID-19 per 1,000,000 people. Counts can include probable cases, where reported.
# * **new_cases_per_million**: New confirmed cases of COVID-19 per 1,000,000 people. Counts can include probable cases, where reported.
# * **new_cases_smoothed_per_million**: New confirmed cases of COVID-19 (7-day smoothed) per 1,000,000 people. Counts can include probable cases, where reported.
# * **total_deaths_per_million**: Total deaths attributed to COVID-19 per 1,000,000 people. Counts can include probable deaths, where reported.
# * **new_deaths_per_million**: New deaths attributed to COVID-19 per 1,000,000 people. Counts can include probable deaths, where reported.
# * **new_deaths_smoothed_per_million**: New deaths attributed to COVID-19 (7-day smoothed) per 1,000,000 people. Counts can include probable deaths, where reported.
# * **reproduction_rate**: Real-time estimate of the effective reproduction rate (R) of COVID-19. See https://github.com/crondonm/TrackingR/tree/main/Estimates-Database
# * **icu_patients**: Number of COVID-19 patients in intensive care units (ICUs) on a given day
# * **icu_patients_per_million**: Number of COVID-19 patients in intensive care units (ICUs) on a given day per 1,000,000 people
# * **hosp_patients**: Number of COVID-19 patients in hospital on a given day
# * **hosp_patients_per_million**: Number of COVID-19 patients in hospital on a given day per 1,000,000 people
# * **weekly_icu_admissions**: Number of COVID-19 patients newly admitted to intensive care units (ICUs) in a given week (reporting date and the preceeding 6 days)
# * **weekly_icu_admissions_per_million**: Number of COVID-19 patients newly admitted to intensive care units (ICUs) in a given week per 1,000,000 people (reporting date and the preceeding 6 days)
# * **weekly_hosp_admissions**: Number of COVID-19 patients newly admitted to hospitals in a given week (reporting date and the preceeding 6 days)
# * **weekly_hosp_admissions_per_million**: Number of COVID-19 patients newly admitted to hospitals in a given week per 1,000,000 people (reporting date and the preceeding 6 days)
# * **total_tests**: Total tests for COVID-19
# * **new_tests**: New tests for COVID-19 (only calculated for consecutive days)
# * **total_tests_per_thousand**: Total tests for COVID-19 per 1,000 people
# * **new_tests_per_thousand**: New tests for COVID-19 per 1,000 people
# * **new_tests_smoothed**: New tests for COVID-19 (7-day smoothed). For countries that don't report testing data on a daily basis, we assume that testing changed equally on a daily basis over any periods in which no data was reported. This produces a complete series of daily figures, which is then averaged over a rolling 7-day window
# * **new_tests_smoothed_per_thousand**: New tests for COVID-19 (7-day smoothed) per 1,000 people
# * **positive_rate**: The share of COVID-19 tests that are positive, given as a rolling 7-day average (this is the inverse of tests_per_case)
# * **tests_per_case**: Tests conducted per new confirmed case of COVID-19, given as a rolling 7-day average (this is the inverse of positive_rate)
# * **tests_units**: Units used by the location to report its testing data
# * **total_vaccinations**: Total number of COVID-19 vaccination doses administered
# * **people_vaccinated**: Total number of people who received at least one vaccine dose
# * **people_fully_vaccinated**: Total number of people who received all doses prescribed by the initial vaccination protocol
# * **total_boosters**: Total number of COVID-19 vaccination booster doses administered (doses administered beyond the number prescribed by the vaccination protocol)
# * **new_vaccinations**: New COVID-19 vaccination doses administered (only calculated for consecutive days)
# * **new_vaccinations_smoothed**: New COVID-19 vaccination doses administered (7-day smoothed). For countries that don't report vaccination data on a daily basis, we assume that vaccination changed equally on a daily basis over any periods in which no data was reported. This produces a complete series of daily figures, which is then averaged over a rolling 7-day window
# * **total_vaccinations_per_hundred**: Total number of COVID-19 vaccination doses administered per 100 people in the total population
# * **people_vaccinated_per_hundred**: Total number of people who received at least one vaccine dose per 100 people in the total population
# * **people_fully_vaccinated_per_hundred**: Total number of people who received all doses prescribed by the initial vaccination protocol per 100 people in the total population
# * **total_boosters_per_hundred**: Total number of COVID-19 vaccination booster doses administered per 100 people in the total population
# * **new_vaccinations_smoothed_per_million**: New COVID-19 vaccination doses administered (7-day smoothed) per 1,000,000 people in the total population
# * **new_people_vaccinated_smoothed**: Daily number of people receiving their first vaccine dose (7-day smoothed)
# * **new_people_vaccinated_smoothed_per_hundred**: Daily number of people receiving their first vaccine dose (7-day smoothed) per 100 people in the total population
# * **stringency_index**: Government Response Stringency Index: composite measure based on 9 response indicators including school closures, workplace closures, and travel bans, rescaled to a value from 0 to 100 (100 = strictest response)
# * **population**: Population (latest available values). See https://github.com/owid/covid-19-data/blob/master/scripts/input/un/population_latest.csv for full list of sources
# * **population_density**: Number of people divided by land area, measured in square kilometers, most recent year available
# * **median_age**: Median age of the population, UN projection for 2020
# * **aged_65_older**: Share of the population that is 65 years and older, most recent year available
# * **aged_70_older**: Share of the population that is 70 years and older in 2015
# * **gdp_per_capita**: Gross domestic product at purchasing power parity (constant 2011 international dollars), most recent year available
# * **extreme_poverty**: Share of the population living in extreme poverty, most recent year available since 2010
# * **cardiovasc_death_rate**: Death rate from cardiovascular disease in 2017 (annual number of deaths per 100,000 people)
# * **diabetes_prevalence**: Diabetes prevalence (% of population aged 20 to 79) in 2017
# * **female_smokers**: Share of women who smoke, most recent year available
# * **male_smokers**: Share of men who smoke, most recent year available
# * **handwashing_facilities**: Share of the population with basic handwashing facilities on premises, most recent year available
# * **hospital_beds_per_thousand**: Hospital beds per 1,000 people, most recent year available since 2010
# * **life_expectancy**: Life expectancy at birth in 2019
# * **human_development_index**: A composite index measuring average achievement in three basic dimensions of human development—a long and healthy life, knowledge and a decent standard of living. Values for 2019, imported from http://hdr.undp.org/en/indicators/137506
# * **excess_mortality**: Percentage difference between the reported number of weekly or monthly deaths in 2020–2021 and the projected number of deaths for the same period based on previous years. For more information, see https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality
# * **excess_mortality_cumulative**: Percentage difference between the cumulative number of deaths since 1 January 2020 and the cumulative projected deaths for the same period based on previous years. For more information, see https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality
# * **excess_mortality_cumulative_absolute**: Cumulative difference between the reported number of deaths since 1 January 2020 and the projected number of deaths for the same period based on previous years. For more information, see https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality
# * **excess_mortality_cumulative_per_million**: Cumulative difference between the reported number of deaths since 1 January 2020 and the projected number of deaths for the same period based on previous years, per million people. For more information, see https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality

# %%
# import packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# import dataset
raw = pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv",parse_dates=['date'])

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# In this section we get to know the COVID-19 dataset. It's crucial before anything, undestanding the data information and distribution before get any insight.
#
# First, it's shown an overview about the data, the definition of any column and the distribution of missing data.
#
# Then, some analysis regarding the features of the countries and their covid-19 situation.

# %% [markdown]
# ## Basic information

# %% [markdown]
# * First entries:

# %%
#@title
raw.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
#@title
print('Data size: ',raw.shape)
# Out:
# Data size:  (193573, 67)

# %%
#@title
print("Data columns:\n", raw.columns.tolist())
# Out:
# Data columns:
# ...

# %%
#@title
print("Columns dtypes:\n",raw.dtypes)
# Out:
# Columns dtypes:
#  iso_code                                           object
# continent                                          object
# location                                           object
# date                                       datetime64[ns]
# total_cases                                       float64
#                                                 ...
# human_development_index                           float64
# excess_mortality_cumulative_absolute              float64
# excess_mortality_cumulative                       float64
# excess_mortality                                  float64
# excess_mortality_cumulative_per_million           float64
# Length: 67, dtype: object

# %% [markdown]
# * Missing data:

# %%
#@title
#Quantity view:
print("Missing values\n\n")
raw.isna().sum()
# Out:
# Missing values
# iso_code                                        0
# continent                                   11243
# location                                        0
# date                                            0
# total_cases                                  7678
#                                             ...
# human_development_index                     38251
# excess_mortality_cumulative_absolute       186967
# excess_mortality_cumulative                186967
# excess_mortality                           186967
# excess_mortality_cumulative_per_million    186967
# Length: 67, dtype: int64

# %%
#@title
print("Missing values in %\n\n")
raw.isna().sum()/raw.__len__()
# Out:
# Missing values in %
# iso_code                                   0.000000
# continent                                  0.058081
# location                                   0.000000
# date                                       0.000000
# total_cases                                0.039665
#                                              ...
# human_development_index                    0.197605
# excess_mortality_cumulative_absolute       0.965873
# excess_mortality_cumulative                0.965873
# excess_mortality                           0.965873
# excess_mortality_cumulative_per_million    0.965873
# Length: 67, dtype: float64

# %%
#@title
print("Distribution of missing data")
plt.figure(figsize=(15,8))
sns.heatmap(raw.isna(),cmap='viridis',cbar=False,yticklabels=False);
# Out:
# Distribution of missing data

# %% [markdown]
# There are a lot of columns with missing data. First of all, there are columns *smoothed* or *per_hundred/thousand*. There columns are derived by other fields that also have missing data. Thus, after filtering these fields, from 67 fields we can filter 26 fields, coming with 41 fields to analyze.
#
# The rows when 'total_cases' is *NaN* are practically null and mostly related to small or isolated locations (e.g.: island), coming in conclusion these locations didn't have enough data or occasions.

# %%
#@title
raw.loc[raw.total_cases.isna()].sample(10)
# Out:
#        iso_code      continent                      location       date  \
# 130824      MNP        Oceania      Northern Mariana Islands 2021-07-10
# 130555      MNP        Oceania      Northern Mariana Islands 2020-10-14
# 71005       GUM        Oceania                          Guam 2022-01-23
# 141827      PRI  North America                   Puerto Rico 2021-05-04
# 183422      VIR  North America  United States Virgin Islands 2020-09-14
# 128662      PRK           Asia                   North Korea 2020-11-02
# 141655      PRI  North America                   Puerto Rico 2020-11-13
# 72338       GGY         Europe                      Guernsey 2022-01-08
# 130771      MNP        Oceania      Northern Mariana Islands 2021-05-18
# 72224       GGY         Europe                      Guernsey 2021-09-16
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 130824          NaN        NaN                 NaN           NaN         NaN
# ...

# %% [markdown]
# The rows when 'total_deaths' is *NaN* means these locations didn't have any death by that date, and it's not uncommon.

# %%
#@title
raw.loc[(~raw.total_cases.isna())&(raw.total_deaths.isna())].sample(10)
# Out:
#        iso_code      continent                          location       date  \
# 69785       GRD  North America                           Grenada 2020-12-22
# 143943      RUS         Europe                            Russia 2020-03-13
# 148779      VCT  North America  Saint Vincent and the Grenadines 2020-07-11
# 154421      SYC         Africa                        Seychelles 2020-10-29
# 148298      SPM  North America         Saint Pierre and Miquelon 2021-06-16
# 146465      KNA  North America             Saint Kitts and Nevis 2020-11-15
# 123563      NCL        Oceania                     New Caledonia 2020-10-24
# 129220      MKD         Europe                   North Macedonia 2020-03-10
# 145939      SHN         Africa                      Saint Helena 2021-08-26
# 17651       BLZ  North America                            Belize 2020-04-05
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %% [markdown]
# Therefore, analyzing the missing data, the fields *'total_cases'* and *'total_deaths'* don't have any inconsistence. The *'icu'* related fields probably are not populated because the locations don't have data from patients in icu or don't have icu and transport the patient to another city. The *'tested'* and *'vaccinated'* patients related fields may suffer from the same situation. Finally, the fields related to countries specifications, such as *'handwashing_facilities'*, are likely to have null data.
#
# We can proceed with the analysis, concluding our data is in order.

# %% [markdown]
# ## Analysis today
#
# * Countries with more cases today:

# %%
#@title
tddata = raw.loc[(raw.date=='2022-06-07') & (~raw.continent.isna())]
tddata.sort_values(by='total_cases',ascending=False)[['continent','location','total_cases']]
# Out:
#             continent                      location  total_cases
# 183242  North America                 United States   85003945.0
# 80849            Asia                         India   43190282.0
# 25007   South America                        Brazil   31266163.0
# 62025          Europe                        France   29713746.0
# 66192          Europe                       Germany   26583016.0
# ...               ...                           ...          ...
# 146224         Africa                  Saint Helena          4.0
# 129201           Asia                   North Korea          1.0
# 71140         Oceania                          Guam          NaN
# 142226  North America                   Puerto Rico          NaN
# 184053  North America  United States Virgin Islands          NaN
#
# [219 rows x 3 columns]

# %% [markdown]
# * Countries with more deaths today:

# %%
#@title
tddata.sort_values(by='total_deaths',ascending=False)[['continent','location','total_deaths','population']]
# Out:
#             continent                      location  total_deaths  \
# 183242  North America                 United States     1009326.0
# 25007   South America                        Brazil      667348.0
# 80849            Asia                         India      524715.0
# 144759         Europe                        Russia      371986.0
# 113333  North America                        Mexico      325042.0
# ...               ...                           ...           ...
# 113841        Oceania          Micronesia (country)           NaN
# 142226  North America                   Puerto Rico           NaN
# 146224         Africa                  Saint Helena           NaN
# 184053  North America  United States Virgin Islands           NaN
# 187972         Europe                       Vatican           NaN
#
#           population
# 183242  3.329151e+08
# 25007   2.139934e+08
# 80849   1.393409e+09
# 144759  1.459120e+08
# 113333  1.302622e+08
# ...              ...
# ...

# %% [markdown]
# * Top 5: Countries with more deaths today:

# %%
#@title
fig,ax = plt.subplots(figsize=(9,6))
tddata.sort_values(by='total_deaths',ascending=False)[['continent','location','total_deaths']][4::-1].plot(x='location',y='total_deaths',kind='barh',ax=ax,legend=False,xlabel='',ylabel='',color='red');
ax.spines['top'].set_visible(False);
ax.spines['right'].set_visible(False);
ax.spines['left'].set_visible(False);
ax.set_title('TOP5: Countries with more COVID-19 deaths');

# %%
print(f"Top 5 countries total deaths (%): {(tddata['total_deaths'].sort_values(ascending=False)[:5].sum()/tddata['total_deaths'].sum()):.2%} from the total deaths")
# Out:
# Top 5 countries total deaths (%): 45.99%

# %% [markdown]
# * Evolution total deaths in the world

# %%
#@title
fig,ax = plt.subplots(figsize=(9,6))
raw.loc[raw.location=='World'].sort_values(by='date').set_index('date')['total_deaths'].plot(xlabel='',ax=ax, color='red');
plt.title("Total deaths by COVID-19 in the world");
ax.spines['top'].set_visible(False);
ax.spines['right'].set_visible(False);

# %% [markdown]
# * GDP x Total Death:

# %%
#@title
fig,ax = plt.subplots(1,3,figsize=(14,4))
tddata.plot(x='gdp_per_capita',y='total_deaths',kind='scatter',s=1,ax=ax[0])
ax[0].spines['top'].set_visible(False);
ax[0].spines['right'].set_visible(False);
ax[0].spines['left'].set_visible(False);
ax[0].set_title('Total deaths x GDP per capita');

tddata.plot(x='population',y='total_deaths',kind='scatter',s=1,ax=ax[1])
ax[1].spines['top'].set_visible(False);
ax[1].spines['right'].set_visible(False);
ax[1].spines['left'].set_visible(False);
ax[1].set_title('Total deaths x Population');

tddata.plot(x='population_density',y='total_deaths',kind='scatter',s=1,ax=ax[2])
ax[2].spines['top'].set_visible(False);
ax[2].spines['right'].set_visible(False);
ax[2].spines['left'].set_visible(False);
ax[2].set_title('Total deaths x Population density');

plt.tight_layout()

# %% [markdown]
# The analysis above combine some features to determine *'total_deaths'* field. It's nothing conclusive, since there are some locations related to a group of countries, i.e., there are values of groups. But it's important to say that *GDP* and *population density* are not correlated.

# %% [markdown]
# ## Brazil EDA
#
# In this section, it will be covered the COVID-19 situation in Brazil, my home country in South America.

# %% [markdown]
# * First death in Brazil:

# %%
#@title
br = raw.loc[raw.location=='Brazil'].copy()
st_death = br.loc[br.total_deaths==1].iloc[0]['date']
print(f"First death: {st_death:'%B %d, %Y'}")
# Out:
# First death: 'March 17, 2020'

# %% [markdown]
# * How long took between 1st case to 1st death:

# %%
#@title
st_case = br.loc[br.total_cases==1].iloc[0]['date']
print(f"First case: {st_case:'%B %d, %Y'}\nFirst death: {st_death:'%B %d, %Y'}\nTime between first case and first death: {(st_death - st_case).days} days")
# Out:
# First case: 'February 26, 2020'
# First death: 'March 17, 2020'
# Time between first case and first death: 20 days

# %% [markdown]
# * Total cases and deaths:

# %%
#@title
fig,ax = plt.subplots(1,2,figsize=(10,4))
br.plot(ax=ax[0],x='date',y='total_cases',xlabel='',legend=False);
ax[0].spines['top'].set_visible(False);
ax[0].spines['right'].set_visible(False);
ax[0].set_title("Total cases in Brazil")

br.plot(ax=ax[1],x='date',y='total_deaths',xlabel='',legend=False);
ax[1].spines['top'].set_visible(False);
ax[1].spines['right'].set_visible(False);
ax[1].set_title("Total deaths in Brazil")

plt.tight_layout();

# %% [markdown]
# * First day of applied vaccine and people fully vaccinated

# %%
#@title
st_vacc = br['date'].loc[br['total_vaccinations']>0].iloc[0]
st_personfullyvacc = br['date'].loc[br['people_fully_vaccinated']>0].iloc[0]

print(f"First day of applied vaccines: {st_vacc:{'%B %d, %Y'}}");
print(f'First day of first people fully vaccinated: {st_personfullyvacc:{"%B %d, %Y"}}')
print(f"Time between: {(st_personfullyvacc-st_vacc).days} days")
# Out:
# First day of applied vaccines: January 17, 2021
# First day of first people fully vaccinated: February 05, 2021
# Time between: 19 days

# %% [markdown]
# * Cases and death per day:

# %%
#@title
fig,ax = plt.subplots(1,2,figsize=(10,4))
br.plot(ax=ax[0],x='date',y=['new_cases','new_cases_smoothed'],xlabel='');
ax[0].spines['top'].set_visible(False);
ax[0].spines['right'].set_visible(False);
ax[0].set_title("Cases per day in Brazil")
ax[0].vlines(x=[st_personfullyvacc],ymin=0,ymax=br['new_cases'].max(),color=['darkgreen'],label='#1 fully vaccinated')
ax[0].legend(loc=0)

br.plot(ax=ax[1],x='date',y=['new_deaths','new_deaths_smoothed'],xlabel='');
ax[1].vlines(x=[st_personfullyvacc],ymin=0,ymax=br['new_deaths'].max(),color=['darkgreen'],label='#1 fully vaccinated')
# br.plot(ax=ax[1],x='date',y='new_deaths_smoothed',xlabel='',color='darkblue');
ax[1].spines['top'].set_visible(False);
ax[1].spines['right'].set_visible(False);
ax[1].set_title("Deaths per day in Brazil")

plt.tight_layout();

# %% [markdown]
# It's possible to visualize how the the increase of cases causes the increase of deaths. It's possible to see three different situations:
# * until December 2021: when the health and distance measures were applyied;
# * December 2021 - Jun 2021: when the government loosen the measures and, by the end, started the effect of the vaccines;
# * Jun 2021 - now: the vaccines shown effective and then government loosen more the measures.

# %% [markdown]
# * HDI specs x pandemic situation

# %% [markdown]
# * Proportion cases x deaths

# %%
fig,ax = plt.subplots(figsize=(9,6))
la = (br['total_deaths']/br['total_cases']).to_frame(name='deathsxcases').join(br['date']).plot(x='date',y='deathsxcases',xlabel='',legend=False,ax=ax, label='deaths per cases');
ax.vlines(x=st_personfullyvacc, ymin=la.get_ylim()[0],ymax=la.get_ylim()[1],color='darkgreen',label='#1 fully vaccinated group')
ax.spines['top'].set_visible(False);
ax.spines['right'].set_visible(False);
ax.set_title('Deaths x Cases in Brazil');
ax.legend(loc=0)

# %% [markdown]
# It's possible to visualize the effects of social distance and heath measures plus the effectiveness of the vaccines in the steady-state proportion of deaths and cases in Brazil until now.

# %% [markdown]
# # Conclusion
#
# The pandemic situation was and still is a global catasthrophe responsible for millions of deaths in the whole world.
#
# It's clear that each country made the efforts as much as possible to overcome this disaster, but unfortunatelly, and no exceptions, lives were taken by the disease.
#
# We can see the top 5 countries with more deaths by COVID-19. Huge countries and commited to the human well being that terribly carried around 45% of the total deaths by COVID-19 in the world.
#
# The deaths rate was increasing, until last month (May 2022), meaning the deaths int he world is decreasing day after day.
#
# Regarding to Brazil efforts, we can visualize the later effects of the health and social distance measures and the effect of the vaccines in the cases and deaths by COVID-19, as shown in the [*Proportion cases x deaths*](https://colab.research.google.com/drive/1cV-08ROYGJV13TV1WBrAsfKdetORgrSE#scrollTo=lbk5FQH0quQc&line=1&uniqifier=1) subsection above.
#
# Therefore, despite the situation mitigated, it's not totally overcome. It's important to notice COVID-19 is a virus, that suffers mutation and can be very contagious and mortal. Also, it can be highlighted the health measures and the vaccines truly have effect, but only for those who respect and fulfill their duties, and their later effects are extremely positive for the whole world.
#
# Thank you for the oportunity to show this importance!
